# %%
import pandas

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-648c9ce3dc4f> in <module>()
# ----> 1 df=pandas.read_csv("IP.csv")
#
# ...

# %%
import os

# %%
os.chdir("C:\Users\elda.zenelaj\Desktop\WinPython-64bit-3.6.3.0Qt5")
# Out:
#   File "<ipython-input-9-09b2808c9c5f>", line 1
#     os.chdir("C:\Users\elda.zenelaj\Desktop\WinPython-64bit-3.6.3.0Qt5")
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
os.chdir("C:/Users/elda.zenelaj/Desktop/WinPython-64bit-3.6.3.0Qt5")

# %%
df=pandas.read_csv("IP.csv")

# %%
df
# Out:
#           Country                                           Operator  \
# 0     Afghanistan             Afghan Wireless Communication Company
# 1     Afghanistan             Afghan Wireless Communication Company
# 2     Afghanistan             Afghan Wireless Communication Company
# 3     Afghanistan             Afghan Wireless Communication Company
# 4     Afghanistan  Emirates Telecommunications Corporation (ETISA...
# 5     Afghanistan    Telecom Development Company Afghanistan Limited
# 6     Afghanistan    Telecom Development Company Afghanistan Limited
# 7         Algeria                                        ATM Mobilis
# 8         Algeria                                        ATM Mobilis
# 9         Algeria                                        ATM Mobilis
# 10        Algeria                                        ATM Mobilis
# 11        Algeria                                        ATM Mobilis
# 12        Algeria                                        ATM Mobilis
# ...

# %%
df.shape
# Out:
# (5169, 7)

# %%
df.set_index("MCC/MNC")
# Out:
#              Country                                           Operator  \
# MCC/MNC
# 41201    Afghanistan             Afghan Wireless Communication Company
# 41201    Afghanistan             Afghan Wireless Communication Company
# 41201    Afghanistan             Afghan Wireless Communication Company
# 41201    Afghanistan             Afghan Wireless Communication Company
# 41250    Afghanistan  Emirates Telecommunications Corporation (ETISA...
# 41220    Afghanistan    Telecom Development Company Afghanistan Limited
# 41220    Afghanistan    Telecom Development Company Afghanistan Limited
# 60301        Algeria                                        ATM Mobilis
# 60301        Algeria                                        ATM Mobilis
# 60301        Algeria                                        ATM Mobilis
# 60301        Algeria                                        ATM Mobilis
# 60301        Algeria                                        ATM Mobilis
# ...

# %%
df
# Out:
#           Country                                           Operator  \
# 0     Afghanistan             Afghan Wireless Communication Company
# 1     Afghanistan             Afghan Wireless Communication Company
# 2     Afghanistan             Afghan Wireless Communication Company
# 3     Afghanistan             Afghan Wireless Communication Company
# 4     Afghanistan  Emirates Telecommunications Corporation (ETISA...
# 5     Afghanistan    Telecom Development Company Afghanistan Limited
# 6     Afghanistan    Telecom Development Company Afghanistan Limited
# 7         Algeria                                        ATM Mobilis
# 8         Algeria                                        ATM Mobilis
# 9         Algeria                                        ATM Mobilis
# 10        Algeria                                        ATM Mobilis
# 11        Algeria                                        ATM Mobilis
# 12        Algeria                                        ATM Mobilis
# ...

# %%
print (u'\U0001f648')
# Out:
# 🙈

# %%
print (u'\U0001f6')
# Out:
# 😁
